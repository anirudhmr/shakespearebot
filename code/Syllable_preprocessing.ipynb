# %%
import nltk
import numpy as np
import sklearn
import copy

# %%
lines = []
with open('../data/shakespeare.txt') as inp:
      for line in inp:
        if len(line.split()) > 2:
            lines.append(line.lower())

# %%
for i in range(len(lines)):
    lines[i] = lines[i][:-1]
    lines[i] = lines[i].replace("'s ", " ")
    lines[i] = lines[i].replace("(", "")
    lines[i] = lines[i].replace(")", "")
    lines[i] = lines[i].replace(":", "")
    lines[i] = lines[i].replace(",", "")
    lines[i] = lines[i].replace("'", "")
    lines[i] = lines[i].replace("?", "")
    lines[i] = lines[i].replace(".", "")

# %%
#print(lines)

# %%
t_lines = []
for i in range(len(lines)):
    t_lines.append(nltk.tokenize.word_tokenize(lines[i]))

# %%
#print(t_lines)

# %%
word_d = {}
counter = 0
for line in t_lines:
    for word in line:
        if word not in word_d:
            word_d[word] = counter
            counter += 1

# %%
t_lines_2 = copy.deepcopy(t_lines)
for i in range(len(t_lines_2)):
    for j in range(len(t_lines_2[i])):
        t_lines_2[i][j] = word_d[t_lines_2[i][j]]

# %%
# print(t_lines_2)

# %%
wd2 = {}
for key in word_d:
    wd2[word_d[key]] = key

def nums_to_words(line):
    ret = []
    for num in line:
        ret.append(wd2[num])
    return ret

# %%
with open('../data/shakespeare.txt') as file:
    all_poems = []
    curr = ''
    for line in file:
        if len(line.strip().split()) > 1:
            curr += line
        elif curr:
            all_poems.append(curr)
            curr = ''
    if curr:
        all_poems.append(curr)

#print(all_poems)

#rhyming_pairs = []
rhyming_pairs = {}
words = []
for i in range(len(all_poems)):
    if i == 99-1 or i == 126-1:
        continue 
    
    # abab cdcd efef gg
    lines = all_poems[i].split("\n")
    #print(lines)
    for i in range(len(lines)):
        #lines[i] = lines[i][:-1]
        lines[i] = lines[i].replace("'s ", " ")
        lines[i] = lines[i].replace("(", "")
        lines[i] = lines[i].replace(")", "")
        lines[i] = lines[i].replace(":", "")
        lines[i] = lines[i].replace(",", "")
        lines[i] = lines[i].replace(".", "")
        lines[i] = lines[i].replace("?", "")
        lines[i] = lines[i].replace("!", "")
        lines[i] = lines[i].replace("'", "")
        lines[i] = lines[i].replace(";", "")

    sub = []
    for line in lines:
        if line:
            last_word = line.rstrip().split(" ")[-1]
            #punct = str.maketrans('', '', ',:;.?!()')
            #last_word = last_word.translate(punct)
            sub.append(last_word.lower())
            #sub.append(last_word)
    words.append(sub)
    sub = []
for wordset in words:
    for i in [0,1,4,5,8,9]:
        if wordset[i] not in rhyming_pairs:
            rhyming_pairs[wordset[i]] = [wordset[i+2]]
        else:
            rhyming_pairs[wordset[i]].append(wordset[i+2])
        if wordset[i+2] not in rhyming_pairs:
            rhyming_pairs[wordset[i+2]] = [wordset[i]]
        else:
            rhyming_pairs[wordset[i+2]].append(wordset[i])
            
            
        #rhyming_pairs.append([wordset[i], wordset[i+2]])
    if wordset[12] not in rhyming_pairs:
            rhyming_pairs[wordset[12]] = [wordset[13]]
    else:
        rhyming_pairs[wordset[12]].append(wordset[13])
    if wordset[13] not in rhyming_pairs:
        rhyming_pairs[wordset[13]] = [wordset[12]]
    else:
        rhyming_pairs[wordset[13]].append(wordset[12])

# %%
print(rhyming_pairs)
# Out:
# {'increase': ['decease', 'cease', 'decrease', 'decease'], 'decease': ['increase', 'lease', 'increase'], 'die': ['memory', 'eye', 'thereby', 'eye', 'lie', 'lie', 'dignity'], 'memory': ['die', 'sky', 'masonry', 'fortify', 'eternity', 'eternity'], 'eyes': ['lies', 'lies', 'lies', 'lies', 'cries', 'lies', 'arise', 'devise', 'prophecies', 'spies', 'lies', 'despise', 'despise', 'lies'], 'lies': ['eyes', 'eyes', 'eyes', 'eyes', 'eyes', 'eyes', 'subtleties', 'eyes'], 'fuel': ['cruel'], 'cruel': ['fuel', 'jewel'], 'ornament': ['content'], 'content': ['ornament', 'spent'], 'spring': ['niggarding', 'king', 'thing', 'sing'], 'niggarding': ['spring'], 'be': ['thee', 'thee', 'thee', 'me', 'thee', 'see', 'thee', 'me', 'decree', 'thee', 'idolatry', 'thee', 'me', 'me', 'thee', 'see', 'me', 'thee', 'thee', 'thee', 'thee', 'i'], 'thee': ['be', 'see', 'be', 'be', 'usury', 'posterity', 'me', 'see', 'me', 'me', 'me', 'see', 'me', 'me', 'me', 'me', 'me', 'me', 'me', 'see', 'me', 'be', 'melancholy', 'me', 'me', 'me', 'me', 'me', 'be', 'me', 'see', 'me', 'be', 'me', 'be', 'free', 'me', 'be', 'be', 'be', 'be', 'me', 'me', 'be', 'thee', 'thee'], 'brow': ['now', 'allow', 'now', 'mow', 'now', 'now', 'now', 'allow'], 'now': ['brow', 'brow', 'brow', 'brow', 'bow', 'how', 'bough', 'brow', 'bow'], 'field': ['held'], 'held': ['field', 'stelled'], 'days': ['praise', 'praise', 'praise', 'praise', 'decays', 'praise', 'praise', 'praise', 'lays', 'praise'], 'praise': ['days', 'days', 'days', 'days', 'days', 'days', 'days', 'days'], 'use': ['excuse', 'abuse', 'muse', 'muse', 'muse', 'abuse'], 'excuse': ['use'], 'mine': ['thine', 'thine', 'shine', 'define', 'line', 'thine', 'thine', 'thine'], 'thine': ['mine', 'mine', 'mine', 'divine', 'mine', 'shine', 'mine'], 'old': ['cold', 'behold', 'told', 'cold', 'told', 'told'], 'cold': ['old', 'uphold', 'behold', 'old'], 'viewest': ['renewest'], 'renewest': ['viewest'], 'another': ['mother', 'mother'], 'mother': ['another', 'another'], 'womb': ['tomb'], 'tomb': ['womb', 'come', 'dumb', 'dumb'], 'husbandry': ['posterity'], 'posterity': ['husbandry', 'thee', 'enmity'], 'see': ['thee', 'thee', 'thee', 'thee', 'be', 'thee', 'be', 'constancy'], 'prime': ['time', 'time', 'time', 'time'], 'time': ['prime', 'prime', 'rhyme', 'rhyme', 'crime', 'rhyme', 'rhyme', 'crime', 'prime', 'prime', 'rhyme', 'rhyme', 'crime', 'crime'], 'spend': ['lend', 'end', 'tend', 'end', 'friend'], 'lend': ['spend', 'tend', 'friend'], 'legacy': ['free'], 'free': ['legacy', 'thee', 'me', 'me'], 'abuse': ['use', 'use'], 'give': ['live', 'live', 'live', 'live', 'live', 'live', 'live'], 'live': ['give', 'give', 'give', 'give', 'give', 'give', 'achieve', 'give'], 'alone': ['gone', 'gone', 'one', 'one', 'one', 'gone', 'gone', 'anon', 'one', 'groan', 'groan', 'prone'], 'gone': ['alone', 'on', 'alone', 'moan', 'alone', 'alone', 'moan'], 'deceive': ['leave', 'leave'], 'leave': ['deceive', 'deceive'], 'frame': ['same', 'same'], 'same': ['frame', 'frame', 'name', 'name'], 'dwell': ['excel', 'bell', 'tell', 'tell', 'tell'], 'excel': ['dwell'], 'on': ['gone', 'groan'], 'there': ['where', 'forbear', 'everywhere', 'dear', 'near'], 'where': ['there', 'clear', 'appear'], 'left': ['bereft'], 'bereft': ['left'], 'glass': ['was'], 'was': ['glass', 'pass'], 'meet': ['sweet', 'sweet'], 'sweet': ['meet', 'meet', 'greet'], 'deface': ['place'], 'place': ['deface', 'grace', 'face', 'case', 'face', 'face'], 'distilled': ['self-killed'], 'self-killed': ['distilled'], 'usury': ['thee'], 'loan': ['one'], 'one': ['loan', 'none', 'alone', 'alone', 'alone', 'alone', 'none'], 'art': ['depart', 'convert', 'heart', 'heart', 'heart', 'heart', 'part', 'heart', 'heart', 'heart'], 'depart': ['art', 'heart'], 'fair': ['heir', 'repair', 'air', 'air', 'heir', 'despair'], 'heir': ['fair', 'fair'], 'light': ['sight', 'sight', 'bright', 'fight', 'fight', 'might'], 'sight': ['light', 'night', 'night', 'night', 'light', 'right', 'delight', 'night', 'night', 'delight', 'night', 'right', 'might', 'might', 'a ...

# %%
rhyming_pair_ids = copy.deepcopy(rhyming_pairs)
for key in rhyming_pairs.keys():
    for i in range(len(rhyming_pairs[key])):
        if rhyming_pairs[key][i] in word_d:
            rhyming_pair_ids[key][i] = word_d[rhyming_pairs[key][i]]    
            
for key in rhyming_pairs.keys():
    rhyming_pair_ids[word_d[key]] = rhyming_pair_ids.pop(key)

# %%
sd = {}
with open('../data/Syllable_dictionary.txt', 'r') as inp:
    for line in inp:
        key, value = (line.split()[0], line.split()[-1])
        if 'E' in value:
            value = line.split()[-2]
        if key[-2:] == "'s":
            key = key[:-2]
        key = key.replace("'", "")
        key = key.replace("(", "")
        key = key.replace(")", "")
        key = key.replace(":", "")
        key = key.replace(",", "")
        key = key.replace("'", "")
        key = key.replace("?", "")
        key = key.replace(".", "")
        #key = key.lower()
        sd[key] = int(value)

# %%
for key in sd.keys():
    if key in word_d:
        if key == 'separation':
            print('hi')
        sd[word_d[key]] = sd.pop(key)

# %%
print(sd)
# Out:
# {'from': 0, 'fairest': 1, 'creatures': 2, 'we': 3, 'desire': 4, 'increase': 5, 'that': 6, 'thereby': 7, 'beauty': 8, 'rose': 9, 'might': 10, 'never': 11, 'die': 12, 'but': 13, 'as': 14, 'the': 15, 'riper': 16, 'should': 17, 'by': 18, 'time': 19, 'decease': 20, 'his': 21, 'tender': 22, 'heir': 23, 'bear': 24, 'memory': 25, 'thou': 26, 'contracted': 27, 'to': 28, 'thine': 29, 'own': 30, 'bright': 31, 'eyes': 32, 'feedst': 33, 'thy': 34, 'light': 35, 'flame': 36, 'with': 37, 'self-substantial': 38, 'fuel': 39, 'making': 40, 'a': 41, 'famine': 42, 'where': 43, 'abundance': 44, 'lies': 45, 'self': 46, 'foe': 47, 'sweet': 48, 'too': 49, 'cruel': 50, 'art': 51, 'now': 52, 'world': 53, 'fresh': 54, 'ornament': 55, 'and': 56, 'only': 57, 'herald': 58, 'gaudy': 59, 'spring': 60, 'within': 61, 'bud': 62, 'buriest': 63, 'content': 64, 'churl': 65, 'makst': 66, 'waste': 67, 'in': 68, 'niggarding': 69, 'pity': 70, 'or': 71, 'else': 72, 'this': 73, 'glutton': 74, 'be': 75, 'eat': 76, 'due': 77, 'grave': 78, 'thee': 79, 'when': 80, 'forty': 81, 'winters': 82, 'shall': 83, 'besiege': 84, 'brow': 85, 'dig': 86, 'deep': 87, 'trenches': 88, 'field': 89, 'youth': 90, 'proud': 91, 'livery': 92, 'so': 93, 'gazed': 94, 'on': 95, 'will': 96, 'tattered': 97, 'weed': 98, 'of': 99, 'small': 100, 'worth': 101, 'held': 102, 'then': 103, 'being': 104, 'asked': 105, 'all': 106, 'treasure': 107, 'lusty': 108, 'days': 109, ';': 110, 'say': 111, 'sunken': 112, 'were': 113, 'an': 114, 'all-eating': 115, 'shame': 116, 'thriftless': 117, 'praise': 118, 'how': 119, 'much': 120, 'more': 121, 'deserved': 122, 'use': 123, 'if': 124, 'couldst': 125, 'answer': 126, 'fair': 127, 'child': 128, 'mine': 129, 'sum': 130, 'my': 131, 'count': 132, 'make': 133, 'old': 134, 'excuse': 135, 'proving': 136, 'succession': 137, 'new': 138, 'made': 139, 'see': 140, 'blood': 141, 'warm': 142, 'feelst': 143, 'it': 144, 'cold': 145, 'look': 146, 'glass': 147, 'tell': 148, 'face': 149, 'viewest': 150, 'is': 151, 'form': 152, 'another': 153, 'whose': 154, 'repair': 155, 'not': 156, 'renewest': 157, 'dost': 158, 'beguile': 159, 'unbless': 160, 'some': 161, 'mother': 162, 'for': 163, 'she': 164, 'uneared': 165, 'womb': 166, 'disdains': 167, 'tillage': 168, 'husbandry': 169, 'who': 170, 'he': 171, 'fond': 172, 'tomb': 173, 'self-love': 174, 'stop': 175, 'posterity': 176, 'calls': 177, 'back': 178, 'lovely': 179, 'april': 180, 'her': 181, 'prime': 182, 'through': 183, 'windows': 184, 'age': 185, 'shalt': 186, 'despite': 187, 'wrinkles': 188, 'golden': 189, 'live': 190, 'remembered': 191, 'single': 192, 'image': 193, 'dies': 194, 'unthrifty': 195, 'loveliness': 196, 'why': 197, 'spend': 198, 'upon': 199, 'legacy': 200, 'nature': 201, 'bequest': 202, 'gives': 203, 'nothing': 204, 'doth': 205, 'lend': 206, 'frank': 207, 'lends': 208, 'those': 209, 'are': 210, 'free': 211, 'beauteous': 212, 'niggard': 213, 'abuse': 214, 'bounteous': 215, 'largess': 216, 'given': 217, 'give': 218, 'profitless': 219, 'usurer': 220, 'great': 221, 'sums': 222, 'yet': 223, 'canst': 224, 'having': 225, 'traffic': 226, 'alone': 227, 'deceive': 228, 'gone': 229, 'what': 230, 'acceptable': 231, 'audit': 232, 'leave': 233, 'unused': 234, 'must': 235, 'tombed': 236, 'which': 237, 'used': 238, 'lives': 239, 'th': 240, 'executor': 241, 'hours': 242, 'gentle': 243, 'work': 244, 'did': 245, 'frame': 246, 'gaze': 247, 'every': 248, 'eye': 249, 'dwell': 250, 'play': 251, 'tyrants': 252, 'very': 253, 'same': 254, 'unfair': 255, 'fairly': 256, 'excel': 257, 'never-resting': 258, 'leads': 259, 'summer': 260, 'hideous': 261, 'winter': 262, 'confounds': 263, 'him': 264, 'there': 265, 'sap': 266, 'checked': 267, 'frost': 268, 'leaves': 269, 'quite': 270, 'oer-snowed': 271, 'bareness': 272, 'distillation': 273, 'left': 274, 'liquid': 275, 'prisoner': 276, 'pent': 277, 'walls': 278, 'effect': 279, 'bereft': 280, 'nor': 281, 'no': 282, 'remembrance': 283, 'was': 284, 'flowers': 285, 'distilled': 286, 'though': 287, 'they': 288, 'meet': 289 ...

# %%
from HMM import *
hmm = unsupervised_HMM(t_lines_2, 20, 10)
# Out:
# Iteration: 10
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-85863bdb739e> in <module>()
#       1 from HMM import *
# ----> 2 hmm = unsupervised_HMM(t_lines_2, 20, 10)
#
# ~/Documents/Caltech/Caltech_2018-19/2nd_Term/CS_155/project3/shakespearebot/code/HMM.py in unsupervised_HMM(X, n_states, N_iters)
#     581     # Train an HMM with unlabeled data.
#     582     HMM = HiddenMarkovModel(A, O)
# --> 583     HMM.unsupervised_learning(X, N_iters)
#     584
#     585     return HMM
#
# ~/Documents/Caltech/Caltech_2018-19/2nd_Term/CS_155/project3/shakespearebot/code/HMM.py in unsupervised_learning(self, X, N_iters)
#     377                                                     * self.A[curr][nxt] \
#     378                                                     * self.O[nxt][x[t]] \
# --> 379                                                     * betas[t + 1][nxt]
#     380
#     381                     # Normalize:
#
# KeyboardInterrupt:

# %%
preva = 0
prevb = 0
for i in range(1, 15):
    if i == 14:
        emission, prevb = hmm.generate_emission(10, i, rhyming_pair_ids, prevb)
    elif i % 2 == 0:
        emission, preva = hmm.generate_emission(10, i, rhyming_pair_ids, preva)
    else:
        emission, prevb = hmm.generate_emission(10, i, rhyming_pair_ids, prevb)
    output = ""
    for elem in nums_to_words(emission):
        output += elem + ' '
    if i != 14:
        output -= " "
        output += ','  
    else:
        output -= " "
        output += '.'
    print(output)
